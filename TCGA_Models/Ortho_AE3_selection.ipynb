# %%
import torch
from torch.utils.data import Dataset, DataLoader, SubsetRandomSampler, random_split
import torch.optim as optim
import pandas as pd
import numpy as np
import os
from collections import defaultdict, Counter
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import KFold
import optuna
from torchmetrics.classification import F1Score
import pickle
import sys
import warnings
warnings.filterwarnings("ignore")
import random
from sklearn.model_selection import ShuffleSplit
from sklearn.cluster import KMeans,DBSCAN,Birch
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score, v_measure_score

sys.path.insert(1, '/home/wangc90/Data_integration/MOCSS/mocss/code/')
from critic import LinearCritic
# from Supcon import SupConLoss
from contrastive_loss import InstanceLoss, ClusterLoss
import evaluation
from sklearn import metrics
from Data_prep import DataSet_Prep, DataSet_construction
random.seed(2023)
torch.manual_seed(2023)

# %%
class SSO_Encoder(nn.Module):
    """
        takes in 3 omic data type measurements for the same set of subjects
    """
    
    def __init__(self, trial):
        
        
        possible_nodes = [32, 64, 128, 256, 512, 1024]
        possible_dropout = [0, 0.1, 0.2, 0.4, 0.6]
        
        ### input dimension for omic 1, omic 2 and omic 3
        self.s1_input_dim = 20531
        self.s2_input_dim = 1046
        
        self.l1_s1_out_dim = trial.suggest_categorical("l1_s1_out_dim", possible_nodes)
        self.l1_s2_out_dim = trial.suggest_categorical("l1_s2_out_dim", possible_nodes)
        self.l1_s12_out_dim = trial.suggest_categorical("l1_s12_out_dim", possible_nodes)
        
        
        self.l2_s1_out_dim = trial.suggest_categorical("l2_s1_out_dim", possible_nodes)
        self.l2_s2_out_dim = trial.suggest_categorical("l2_s2_out_dim", possible_nodes)
        self.l2_s12_out_dim = trial.suggest_categorical("l2_s12_out_dim", possible_nodes)

        
        self.l3_s1_out_dim = trial.suggest_categorical("l3_s1_out_dim", possible_nodes)
        self.l3_s2_out_dim = trial.suggest_categorical("l3_s2_out_dim", possible_nodes)
        self.l3_s12_out_dim = trial.suggest_categorical("l3_s12_out_dim", possible_nodes)
        
        ### embedding for z1, z2 and z12 have to have the same dimension for the 
        ### orthogonal losss based on MOCSS to work
        self.embed_s1_out_dim = trial.suggest_categorical("embed_s1_out_dim", possible_nodes)
        self.embed_s2_out_dim = self.embed_s1_out_dim
        self.embed_s12_out_dim = self.embed_s1_out_dim
        
        
        
        super(SSO_Encoder, self).__init__()
        
        ### encoder structure: 
        
        ######################################################################################
        self.l1_s1 = nn.Linear(self.s1_input_dim, self.l1_s1_out_dim)
        self.l1_s1_bn = nn.BatchNorm1d(self.l1_s1_out_dim)
        l1_s1_drop_rate = trial.suggest_categorical("l1_s1_drop_rate", possible_dropout)
        self.drop_l1_s1 = nn.Dropout(p=l1_s1_drop_rate)
        
        
        self.l2_s1 = nn.Linear(self.l1_s1_out_dim,  self.l2_s1_out_dim)
        self.l2_s1_bn = nn.BatchNorm1d(self.l2_s1_out_dim)
        l2_s1_drop_rate = trial.suggest_categorical("l2_s1_drop_rate", possible_dropout)
        self.drop_l2_s1 = nn.Dropout(p=l2_s1_drop_rate)
        
        
        self.l3_s1 = nn.Linear(self.l2_s1_out_dim, self.l3_s1_out_dim)
        self.l3_s1_bn = nn.BatchNorm1d(self.l3_s1_out_dim)
        l3_s1_drop_rate = trial.suggest_categorical("l3_s1_drop_rate", possible_dropout)
        self.drop_l3_s1 = nn.Dropout(p=l3_s1_drop_rate)
        
        
        self.embed_s1 = nn.Linear(self.l3_s1_out_dim, self.embed_s1_out_dim)
        self.embed_s1_bn = nn.BatchNorm1d(self.embed_s1_out_dim)
        embed_s1_drop_rate = trial.suggest_categorical("embed_s1_drop_rate", possible_dropout)
        self.drop_embed_s1 = nn.Dropout(p=embed_s1_drop_rate)
        
        
        ###########################################################################################
        self.l1_s2 = nn.Linear(self.s2_input_dim, self.l1_s2_out_dim)
        self.l1_s2_bn = nn.BatchNorm1d(self.l1_s2_out_dim)
        l1_s2_drop_rate = trial.suggest_categorical("l1_s2_drop_rate", possible_dropout)
        self.drop_l1_s2 = nn.Dropout(p=l1_s2_drop_rate)
        
        
        self.l2_s2 = nn.Linear(self.l1_s2_out_dim,  self.l2_s2_out_dim)
        self.l2_s2_bn = nn.BatchNorm1d(self.l2_s2_out_dim)
        l2_s2_drop_rate = trial.suggest_categorical("l2_s2_drop_rate", possible_dropout)
        self.drop_l2_s2 = nn.Dropout(p=l2_s2_drop_rate)
        
        
        self.l3_s2 = nn.Linear(self.l2_s2_out_dim, self.l3_s2_out_dim)
        self.l3_s2_bn = nn.BatchNorm1d(self.l3_s2_out_dim)
        l3_s2_drop_rate = trial.suggest_categorical("l3_s2_drop_rate", possible_dropout)
        self.drop_l3_s2 = nn.Dropout(p=l3_s2_drop_rate)
        
        
        self.embed_s2 = nn.Linear(self.l3_s2_out_dim, self.embed_s2_out_dim)
        self.embed_s2_bn = nn.BatchNorm1d(self.embed_s2_out_dim)
        embed_s2_drop_rate = trial.suggest_categorical("embed_s2_drop_rate", possible_dropout)
        self.drop_embed_s2 = nn.Dropout(p=embed_s2_drop_rate)
        
        
        
        ##########################################################################################
        
        self.l1_s12 = nn.Linear(self.s1_input_dim + self.s2_input_dim,
                                 self.l1_s12_out_dim)
        self.l1_s12_bn = nn.BatchNorm1d(self.l1_s12_out_dim)
        l1_s12_drop_rate = trial.suggest_categorical("l1_s12_drop_rate", possible_dropout)
        self.drop_l1_s12 = nn.Dropout(p=l1_s12_drop_rate)
        
        
        self.l2_s12 = nn.Linear(self.l1_s12_out_dim,  self.l2_s12_out_dim)
        self.l2_s12_bn = nn.BatchNorm1d(self.l2_s12_out_dim)
        l2_s12_drop_rate = trial.suggest_categorical("l2_s12_drop_rate", possible_dropout)
        self.drop_l2_s12 = nn.Dropout(p=l2_s12_drop_rate)
        
        
        self.l3_s12 = nn.Linear(self.l2_s12_out_dim, self.l3_s12_out_dim)
        self.l3_s12_bn = nn.BatchNorm1d(self.l3_s12_out_dim)
        l3_s12_drop_rate = trial.suggest_categorical("l3_s12_drop_rate", possible_dropout)
        self.drop_l3_s12 = nn.Dropout(p=l3_s12_drop_rate)
        
        
        self.embed_s12 = nn.Linear(self.l3_s12_out_dim, self.embed_s12_out_dim)
        self.embed_s12_bn = nn.BatchNorm1d(self.embed_s12_out_dim)
        embed_s12_drop_rate = trial.suggest_categorical("embed_s12_drop_rate", possible_dropout)
        self.drop_embed_s12 = nn.Dropout(p=embed_s12_drop_rate)
        

    def forward(self, s1, s2, labels=None):
        
        #############################################################
        s1_ = self.drop_l1_s1(self.l1_s1_bn(F.relu(self.l1_s1(s1))))
        s1_ = self.drop_l2_s1(self.l2_s1_bn(F.relu(self.l2_s1(s1_))))
        s1_ = self.drop_l3_s1(self.l3_s1_bn(F.relu(self.l3_s1(s1_))))
        z1 = self.drop_embed_s1(self.embed_s1_bn(F.relu(self.embed_s1(s1_))))
        
        
        
        s2_ = self.drop_l1_s2(self.l1_s2_bn(F.relu(self.l1_s2(s2))))
        s2_ = self.drop_l2_s2(self.l2_s2_bn(F.relu(self.l2_s2(s2_))))
        s2_ = self.drop_l3_s2(self.l3_s2_bn(F.relu(self.l3_s2(s2_))))
        z2 = self.drop_embed_s2(self.embed_s2_bn(F.relu(self.embed_s2(s2_))))
        
        
        
        
        ### concatenate s1, s2 together for the joint embedding
        s12 = torch.cat((s1, s2), dim=1)
        s12_ = self.drop_l1_s12(self.l1_s12_bn(F.relu(self.l1_s12(s12))))
        s12_ = self.drop_l2_s12(self.l2_s12_bn(F.relu(self.l2_s12(s12_))))
        s12_ = self.drop_l3_s12(self.l3_s12_bn(F.relu(self.l3_s12(s12_))))
        z12 = self.drop_embed_s12(self.embed_s12_bn(F.relu(self.embed_s12(s12_))))
        
        
        return z1, z2, z12, labels
    
    

class SSO_Decoder(nn.Module):
    
    ### decoder: construct s1 and s2  based on the concatenated z12 z1 and z2
    ### and calculate the reconstruction loss separately for s1 and s2
    
    def __init__(self, trial):
        
        
        possible_nodes = [32, 64, 128, 256, 512, 1024]
        possible_dropout = [0, 0.1, 0.2, 0.4, 0.6]
        
        self.s1_input_dim = SSO_Encoder(trial).s1_input_dim
        self.s2_input_dim = SSO_Encoder(trial).s2_input_dim
        
        self.s1_embed_dim = SSO_Encoder(trial).embed_s1_out_dim
        self.s2_embed_dim = SSO_Encoder(trial).embed_s2_out_dim
        self.s12_embed_dim = SSO_Encoder(trial).embed_s12_out_dim
        
        
        self._embed_s1_out_dim = trial.suggest_categorical("_embed_s1_out_dim", possible_nodes)
        self._l3_s1_out_dim = trial.suggest_categorical("_l3_s1_out_dim", possible_nodes)
        self._l2_s1_out_dim = trial.suggest_categorical("_l2_s1_out_dim", possible_nodes)
        self._l1_s1_out_dim = self.s1_input_dim
        
        
        self._embed_s2_out_dim = trial.suggest_categorical("_embed_s2_out_dim", possible_nodes)
        self._l3_s2_out_dim = trial.suggest_categorical("_l3_s2_out_dim", possible_nodes)
        self._l2_s2_out_dim = trial.suggest_categorical("_l2_s2_out_dim", possible_nodes)
        self._l1_s2_out_dim = self.s2_input_dim
        
        
        super(SSO_Decoder, self).__init__()
        
        
        self._embed_s1 = nn.Linear(self.s1_embed_dim + self.s2_embed_dim + self.s12_embed_dim,\
                                   self._embed_s1_out_dim)
        
        self._embed_s1_bn = nn.BatchNorm1d(self._embed_s1_out_dim)
        _embed_s1_drop_rate = trial.suggest_categorical("_embed_s1_drop_rate", possible_dropout)
        self._drop_embed_s1 = nn.Dropout(p=_embed_s1_drop_rate)
        
        
        self._l3_s1 = nn.Linear(self._embed_s1_out_dim, self._l3_s1_out_dim)
        self._l3_s1_bn = nn.BatchNorm1d(self._l3_s1_out_dim)
        _l3_s1_drop_rate = trial.suggest_categorical("_l3_s1_drop_rate", possible_dropout)
        self._drop_l3_s1 = nn.Dropout(p=_l3_s1_drop_rate)
        
        
        self._l2_s1 = nn.Linear(self._l3_s1_out_dim, self._l2_s1_out_dim)
        self._l2_s1_bn = nn.BatchNorm1d(self._l2_s1_out_dim)
        _l2_s1_drop_rate = trial.suggest_categorical("_l2_s1_drop_rate", possible_dropout)
        self._drop_l2_s1 = nn.Dropout(p=_l2_s1_drop_rate)
        
        
        self._l1_s1 = nn.Linear(self._l2_s1_out_dim, self._l1_s1_out_dim)
        self._l1_s1_bn = nn.BatchNorm1d(self._l1_s1_out_dim)
        _l1_s1_drop_rate = trial.suggest_categorical("_l1_s1_drop_rate", possible_dropout)
        self._drop_l1_s1 = nn.Dropout(p=_l1_s1_drop_rate)
        
        #############################################################################

        self._embed_s2 = nn.Linear(self.s1_embed_dim + self.s2_embed_dim + self.s12_embed_dim,\
                                   self._embed_s2_out_dim)
        
        self._embed_s2_bn = nn.BatchNorm1d(self._embed_s2_out_dim)
        _embed_s2_drop_rate = trial.suggest_categorical("_embed_s2_drop_rate", possible_dropout)
        self._drop_embed_s2 = nn.Dropout(p=_embed_s2_drop_rate)
        
        
        self._l3_s2 = nn.Linear(self._embed_s2_out_dim, self._l3_s2_out_dim)
        self._l3_s2_bn = nn.BatchNorm1d(self._l3_s2_out_dim)
        _l3_s2_drop_rate = trial.suggest_categorical("_l3_s2_drop_rate", possible_dropout)
        self._drop_l3_s2 = nn.Dropout(p=_l3_s2_drop_rate)
        
        
        self._l2_s2 = nn.Linear(self._l3_s2_out_dim, self._l2_s2_out_dim)
        self._l2_s2_bn = nn.BatchNorm1d(self._l2_s2_out_dim)
        _l2_s2_drop_rate = trial.suggest_categorical("_l2_s2_drop_rate", possible_dropout)
        self._drop_l2_s2 = nn.Dropout(p=_l2_s2_drop_rate)
        
        
        self._l1_s2 = nn.Linear(self._l2_s2_out_dim, self._l1_s2_out_dim)
        self._l1_s2_bn = nn.BatchNorm1d(self._l1_s2_out_dim)
        _l1_s2_drop_rate = trial.suggest_categorical("_l1_s2_drop_rate", possible_dropout)
        self._drop_l1_s2 = nn.Dropout(p=_l1_s2_drop_rate)
        
        
        
    def forward(self, z1, z2, z12):
        
        z_all = torch.cat((z1, z2, z12), dim=1)
        
        
        s1_ = self._drop_embed_s1(self._embed_s1_bn(F.relu(self._embed_s1(z_all))))
        s1_ = self._drop_l3_s1(self._l3_s1_bn(F.relu(self._l3_s1(s1_))))
        s1_ = self._drop_l2_s1(self._l2_s1_bn(F.relu(self._l2_s1(s1_))))
        s1_ = self._drop_l1_s1(self._l1_s1_bn(F.relu(self._l1_s1(s1_))))
        
        s1_out = torch.sigmoid(s1_)
        
        
        
        s2_ = self._drop_embed_s2(self._embed_s2_bn(F.relu(self._embed_s2(z_all))))
        
        s2_ = self._drop_l3_s2(self._l3_s2_bn(F.relu(self._l3_s2(s2_))))
        s2_ = self._drop_l2_s2(self._l2_s2_bn(F.relu(self._l2_s2(s2_))))
        s2_ = self._drop_l1_s2(self._l1_s2_bn(F.relu(self._l1_s2(s2_))))
        
        s2_out = torch.sigmoid(s2_)
        
        return s1_out, s2_out

    
class SSO_AE(nn.Module):
    def __init__(self, trial):
        
        super(SSO_AE, self).__init__()
        
        self.encoder = SSO_Encoder(trial)
        self.decoder = SSO_Decoder(trial)

    def forward(self, s1, s2, labels):
        
        ### encoder ouput for embeddings
        z1, z2, z12, labels = self.encoder(s1, s2, labels)
        
        ### decoder output for reconstructed input
        s1_out, s2_out = self.decoder(z1, z2, z12)
        
        return z1, z2, z12, s1_out, s2_out, labels

# %%
def CustomLoss(s1, s2, s1_out, s2_out,
                z1, z2, z12, labels):
    
    """
        Ortho_AE3
    """

    ### normalize the feature vector with length 1
    s1_out = F.normalize(s1_out, p=2, dim=1)
    s2_out = F.normalize(s2_out, p=2, dim=1)
    
    
    s1 = F.normalize(s1, p=2, dim=1)
    s2 = F.normalize(s2, p=2, dim=1)

    recon_loss = torch.linalg.matrix_norm(s1_out-s1) + torch.linalg.matrix_norm(s2_out-s2)

    
    z1 = F.normalize(z1, p=2, dim=1)
    z2 = F.normalize(z2, p=2, dim=1)
    z12 = F.normalize(z12, p=2, dim=1)
    
    z12_t = torch.t(z12)
    z2_t = torch.t(z2)
    
    
    z12_t_z1 = torch.matmul(z12_t, z1)
    z12_t_z2 = torch.matmul(z12_t, z2)
#     z2_t_z1 = torch.matmul(z2_t, z1)

#### shared and specific
    z12_t_z1_diag = torch.diagonal(z12_t_z1, 0) ## get the main diagnol
    z12_t_z1_diag_square_sum = torch.sum(torch.square(z12_t_z1_diag)) ## get squared term to make it close to 0 in magnitude

    z12_t_z2_diag = torch.diagonal(z12_t_z2, 0) ## get the main diagnol
    z12_t_z2_diag_square_sum = torch.sum(torch.square(z12_t_z2_diag))
    
    ortho_loss = z12_t_z1_diag_square_sum + z12_t_z2_diag_square_sum
    
#     z12_t_z1_cost = torch.linalg.matrix_norm(z12_t_z1)
#     z12_t_z2_cost = torch.linalg.matrix_norm(z12_t_z2)
#     z2_t_z1_cost = torch.linalg.matrix_norm(z2_t_z1)
    

    
#     ortho_loss = z12_t_z1_cost + z12_t_z2_cost #+ z2_t_z1_cost
    
    return recon_loss, ortho_loss

# %%
def setup_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)

# %%
### create a training function that is seamless for all different models
def Objective(device, trial, fold, model, optimizer,
              epochs, train_loader, val_loader, ortho_multiplier):

    
    #### model training on the training set
    
    for epoch in range(epochs):
        
        model.train()
        # record the training loss
        total_recon_loss = 0.0
        total_ortho_loss = 0.0
        total_train = 0.0
        
        
        for iteration_index, train_batch in enumerate(train_loader):
            view1_train_data, view2_train_data, train_labels = train_batch

            view1_train_data = view1_train_data.type(torch.float32).to(device)
            view2_train_data = view2_train_data.type(torch.float32).to(device)
            train_labels = train_labels.type(torch.LongTensor).to(device)
            
            z1, z2, z12, s1_out, s2_out, labels = \
                model(view1_train_data, view2_train_data, train_labels)
            
#             print(z123.shape, s1_out.shape, s2_out.shape, s3_out.shape)
            train_size = z12.size()[0]
    
            recon_loss, ortho_loss = CustomLoss(s1=view1_train_data,\
                                             s2=view2_train_data,\
                                             s1_out=s1_out,\
                                             s2_out=s2_out,\
                                             z1=z1,\
                                             z2=z2,\
                                             z12=z12,\
                                             labels=train_labels)
            
#             print(clustering_loss)
            
            loss = recon_loss + (ortho_loss * ortho_multiplier)
            # backward pass
            optimizer.zero_grad()  # empty the gradient from last round

            # calculate the gradient
            loss.backward()
            
            
#             print(model.weight.grad)
            # update the parameters
            optimizer.step()
            
            total_train += train_size
#             total_clustering_loss += (clustering_loss.item()*train_size)
            total_recon_loss += recon_loss.item()
            total_ortho_loss += ortho_loss.item()

        
        if (epoch + 1) % 10 == 0: 
            print(f'fold {fold+1} epoch {epoch+1}')
            print(f'average train recon loss is: {total_recon_loss/total_train}')
            print(f'average train ortho loss is: {total_ortho_loss/total_train}')
            
            
    #### model evaluation on the validation set at the last epoch and return acc
    
    model.eval()
    with torch.no_grad():

        total_recon_loss = 0.0
        total_val = 0.0

        for iteration_index, val_batch in enumerate(val_loader):
            view1_val_data, view2_val_data, val_labels = val_batch

            view1_val_data = view1_val_data.type(torch.float32).to(device)
            view2_val_data = view2_val_data.type(torch.float32).to(device)
            val_labels = val_labels.type(torch.LongTensor).to(device)

            z1_val, z2_val, z12_val, s1_out_val, s2_out_val, labels_val = \
                model(view1_val_data, view2_val_data, val_labels)

            val_size = z12.size()[0]

            recon_loss, ortho_loss = CustomLoss(s1=view1_val_data,\
                                         s2=view2_val_data,\
                                         s1_out=s1_out_val,\
                                         s2_out=s2_out_val,\
                                         z1=z1_val,\
                                         z2=z2_val,\
                                         z12=z12_val,\
                                         labels=labels_val)

            total_val += val_size
            total_recon_loss += recon_loss.item()
        avg_recon_loss = total_recon_loss / total_val
    return avg_recon_loss



class Objective_CV:

    def __init__(self, cv, model, dataset, val_loss_folder):

        self.cv = cv  ## number of CV
        self.model = model  ## pass the corresponding model
        self.dataset = dataset  ## the corresponding dataset object
        self.val_loss_folder = val_loss_folder  ## folder to store the cross_validation accuracy

    def __call__(self, trial):

        ### just use the sequence feature for now
        device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

        lr = trial.suggest_float("lr", 1e-5, 1e-2, log=True)
#         lr = 0.001
        l2_lambda = trial.suggest_float("l2_lambda", 1e-8, 1e-5, log=True)
#         l2_lambda = 0
        batch_size = trial.suggest_categorical("batch_size", [32, 64, 128, 256, 512])
    
        ### optimize the multiplier for orthogonal loss
        ortho_multiplier = trial.suggest_categorical("ortho_multiplier", [1e-3, 1e-2, 1e-1, 1e0, 1e1, 1e2, 1e3])

        ### optimize epoch number
        epochs = trial.suggest_categorical("epoch", [30, 60, 90, 120, 150])
        
        ## choose the optimizer
#         optimizer_name = trial.suggest_categorical("optimizer", ["Adam", "RMSprop","Adagrad"])
        optimizer_name = 'Adam'

        kfold = KFold(n_splits=self.cv, shuffle=True)

        setup_seed(21)
        
        val_fold_loss = []
                    
        for fold, (train_index, val_index) in enumerate(kfold.split(np.arange(len(self.dataset)))):

            ### get the train and val loader
            train_subset = torch.utils.data.Subset(self.dataset, train_index)
            train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
            

            val_subset = torch.utils.data.Subset(self.dataset, val_index)
            val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=True)
            

            ## model should be initilized here for each fold to have a new model with same hyperparameters

            ### for the model the process the concatenated upper and lower the is_rcm is always False
            Model = self.model(trial).to(device=device)
#             print(Model)
            optimizer = getattr(optim, optimizer_name)(Model.parameters(), lr=lr, weight_decay=l2_lambda)

            val_loss = Objective(device, trial, fold=fold, model=Model, optimizer=optimizer,
                                 epochs=epochs, train_loader=train_loader, val_loader=val_loader,
                                    ortho_multiplier=ortho_multiplier)

            val_fold_loss.append(val_loss)
            
        avg_val_loss = np.mean(val_fold_loss)

        val_loss_path = f"{self.val_loss_folder}/val_loss.csv"

        val_loss_str = '\t'.join([str(i) for i in val_fold_loss])
        with open(val_loss_path, 'a') as f:
            f.write('trial' + str(trial.number) + '\t' + val_loss_str + '\n')

        return avg_val_loss

# %%
def Ortho_AE_model_selection(num_trial):

    ### where to save the 3-fold CV validation acc

    val_loss_folder = '/home/wangc90/Data_integration/TCGA_model_outputs/model_selection_outputs/Ortho_AE_3/val_loss'
    
    ### wehre to save the detailed optuna results
    optuna_folder = '/home/wangc90/Data_integration/TCGA_model_outputs/model_selection_outputs/Ortho_AE_3/optuna'
    
    
    combined_exp_df = pd.read_csv('/home/wangc90/Data_integration/TCGA_data/TCGA_primary_tumor_data/combined_exp_df.csv', sep='\t')
    combined_miRNA_df = pd.read_csv('/home/wangc90/Data_integration/TCGA_data/TCGA_primary_tumor_data/combined_miRNA_df.csv', sep='\t')

    labels = pd.read_csv('/home/wangc90/Data_integration/TCGA_data/TCGA_primary_tumor_data/labels.csv', sep='\t')['0']

    dataset_prep = DataSet_Prep(data1=combined_exp_df, data2=combined_miRNA_df, label=labels, training_prop=0.8)

    train_key, test_key = dataset_prep.get_train_test_keys()

    feature1_tensors, feature2_tensors, label_tensors = dataset_prep.to_tensor(train_key)
    
    train_dataset = DataSet_construction(feature1_tensors, feature2_tensors, label_tensors)

    print(len(train_dataset))
    
    
    study = optuna.create_study(pruner=optuna.pruners.MedianPruner(n_warmup_steps=2),
                                direction='minimize')
    
    
    study.optimize(Objective_CV(cv=5, model= SSO_AE,
                                dataset=train_dataset,
                                val_loss_folder=val_loss_folder),
                   n_trials=num_trial, gc_after_trial=True)


    pruned_trials = [t for t in study.trials if t.state == optuna.trial.TrialState.PRUNED]
    complete_trials = [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE]
    with open(optuna_folder+'/optuna.txt', 'a') as f:
        f.write("Study statistics: \n")
        f.write(f"Number of finished trials: {len(study.trials)}\n")
        f.write(f"Number of pruned trials: {len(pruned_trials)}\n")
        f.write(f"Number of complete trials: {len(complete_trials)}\n")

        f.write("Best trial:\n")
        trial = study.best_trial
        f.write(f"Value: {trial.value}\n")
        f.write("Params:\n")
        for key, value in trial.params.items():
            f.write(f"{key}:{value}\n")

    df = study.trials_dataframe().drop(['state','datetime_start','datetime_complete','duration','number'], axis=1)
    df.to_csv(optuna_folder + '/optuna.csv', sep='\t', index=None)

# %%
import time

# Record the start time
start_time = time.time()


Ortho_AE_model_selection(num_trial=100)

# Record the end time
end_time = time.time()

# Calculate the elapsed time
elapsed_time = end_time - start_time

print(f"Elapsed time: {elapsed_time/60} minutes")
# Out:
# [I 2024-06-12 20:27:32,719] A new study created in memory with name: no-name-52521ec2-25cd-493f-ad2e-68881e43f690
# feature1 and feature2 are being scaled with MinMaxScaler
# 1494
# fold 1 epoch 10
# average train recon loss is: 0.09971086829277262
# average train ortho loss is: 0.020087630579162342
# fold 1 epoch 20
# average train recon loss is: 0.09838501998071392
# average train ortho loss is: 0.021341503813675756
# fold 1 epoch 30
# average train recon loss is: 0.09749299691810767
# average train ortho loss is: 0.01824368552682789
# fold 1 epoch 40
# average train recon loss is: 0.09701659390118332
# average train ortho loss is: 0.0135874955723974
# fold 1 epoch 50
# average train recon loss is: 0.09665771228997777
# average train ortho loss is: 0.015475759346614822
# fold 1 epoch 60
# average train recon loss is: 0.09633452124176664
# average train ortho loss is: 0.013611743839216033
# fold 1 epoch 70
# average train recon loss is: 0.0960546517471888
# average train ortho loss is: 0.014268371350595641
# fold 1 epoch 80
# average train recon loss is: 0.09573193793516278
# average train ortho loss is: 0.015871308538205453
# fold 1 epoch 90
# average train recon loss is: 0.09535598435661284
# average train ortho loss is: 0.014605234856386064
# fold 1 epoch 100
# average train recon loss is: 0.09504227738001357
# average train ortho loss is: 0.013611350199168697
# fold 1 epoch 110
# average train recon loss is: 0.09468948491946425
# average train ortho loss is: 0.011659964158445222
# fold 1 epoch 120
# average train recon loss is: 0.09434159250937744
# average train ortho loss is: 0.011202605399127784
# fold 1 epoch 130
# average train recon loss is: 0.09402888629227003
# average train ortho loss is: 0.010241396756351741
# fold 1 epoch 140
# average train recon loss is: 0.09371884078660271
# average train ortho loss is: 0.010360187466673273
# fold 1 epoch 150
# average train recon loss is: 0.0933938828472313
# average train ortho loss is: 0.009936725544630234
# fold 2 epoch 10
# average train recon loss is: 0.09965688154787199
# average train ortho loss is: 0.018799271643411164
# fold 2 epoch 20
# average train recon loss is: 0.09821318941635068
# average train ortho loss is: 0.01750191285520418
# fold 2 epoch 30
# average train recon loss is: 0.09735292091529239
# average train ortho loss is: 0.016590201405800534
# fold 2 epoch 40
# average train recon loss is: 0.09692454318122384
# average train ortho loss is: 0.01576349585624918
# fold 2 epoch 50
# average train recon loss is: 0.09658433443332816
# average train ortho loss is: 0.015963266284894743
# fold 2 epoch 60
# average train recon loss is: 0.096329076918598
# average train ortho loss is: 0.014637567208900611
# fold 2 epoch 70
# average train recon loss is: 0.09605419206818776
# average train ortho loss is: 0.013734084093421074
# fold 2 epoch 80
# average train recon loss is: 0.09574734037391311
# average train ortho loss is: 0.01324709209936932
# fold 2 epoch 90
# average train recon loss is: 0.09544111116161905
# average train ortho loss is: 0.012124023277889235
# fold 2 epoch 100
# average train recon loss is: 0.09516192639721986
# average train ortho loss is: 0.013175836267830438
# fold 2 epoch 110
# average train recon loss is: 0.09484864558136114
# average train ortho loss is: 0.012107662376499575
# fold 2 epoch 120
# average train recon loss is: 0.0945494967025693
# average train ortho loss is: 0.010535886497178336
# fold 2 epoch 130
# average train recon loss is: 0.09429057612079955
# average train ortho loss is: 0.010114244437117956
# fold 2 epoch 140
# average train recon loss is: 0.09393891530056878
# average train ortho loss is: 0.011821526762830662
# fold 2 epoch 150
# average train recon loss is: 0.09374308885390789
# average train ortho loss is: 0.009870743452255696
# fold 3 epoch 10
# average train recon loss is: 0.09950022039054328
# average train ortho loss is: 0.019310651563700272
# fold 3 epoch 20
# average train recon loss is: 0.0981073658835439
# average train ortho loss is: 0.01759451104008503
# fold 3 epoch 30
# average train recon loss is: 0.09736033483529191
# average train ortho loss is: 0.015593503209836313
# fold 3 epoch 40
# average train recon loss is: 0.09695447019952112
# average train ortho loss is: 0.017396800188838688
# fold 3 epoch 50
# average train recon loss is: 0.09659566520148241
# average train ortho loss is: 0.014844898399448794
# fold 3 epoch 60
# average train recon loss is: 0.09629635192360339
# average train ortho loss is: 0.014711180890454407
# fold 3 epoch 70
# average train recon loss is: 0.09597005165770463
# average train ortho loss is: 0.013973532361465518
# fold 3 epoch 80
# average train recon loss is: 0.09571317090150203
# average train ortho loss is: 0.012054359663480495
# fold 3 epoch 90
# average train recon loss is: 0.09543747044008646
# average train ortho loss is: 0.013153288853218367
# fold 3 epoch 100
# average train recon loss is: 0.09513187488252647
# average train ortho loss is: 0.01384545848958163
# fold 3 epoch 110
# average train recon loss is: 0.0948498490465236
# average train ortho loss is: 0.011968553415402209
# fold 3 epoch 120
# average train recon loss is: 0.0945401052052007
# average train ortho loss is: 0.012039900225076715
# fold 3 epoch 130
# average train recon loss is: 0.09426114389587147
# average train ortho loss is: 0.01295337597196571
# fold 3 epoch 140
# average train recon loss is: 0.09394820145483296
# average train ortho loss is: 0.009578238172012393
# fold 3 epoch 150
# average train recon loss is: 0.09366417409984637
# average train ortho loss is: 0.010435411720595101
# fold 4 epoch 10
# average train recon loss is: 0.09949293256304753
# average train ortho loss is: 0.019540323273407365
# fold 4 epoch 20
# average train recon loss is: 0.0981576129482381
# average train ortho loss is: 0.018535556154769834
# fold 4 epoch 30
# average train recon loss is: 0.09740608247254184
# average train ortho loss is: 0.01678392059134639
# fold 4 epoch 40
# average train recon loss is: 0.09695019263103916
# average train ortho loss is: 0.01541300378583964
# fold 4 epoch 50
# average train recon loss is: 0.09660653469452798
# average train ortho loss is: 0.01424224067432611
# fold 4 epoch 60
# average train recon loss is: 0.09634739704211885
# average train ortho loss is: 0.014685661124385052
# fold 4 epoch 70
# average train recon loss is: 0.09604029954726725
# average train ortho loss is: 0.01446299233695952
# fold 4 epoch 80
# average train recon loss is: 0.09573166180854063
# average train ortho loss is: 0.01296987653277409
# fold 4 epoch 90
# average train recon loss is: 0.09537854533813987
# average train ortho loss is: 0.013027516768068449
# fold 4 epoch 100
# average train recon loss is: 0.09508159429957179
# average train ortho loss is: 0.012490857894450551
# fold 4 epoch 110
# average train recon loss is: 0.09476202481960153
# average train ortho loss is: 0.012601807725978197
# fold 4 epoch 120
# average train recon loss is: 0.0944357293420257
# average train ortho loss is: 0.012311421079116884
# fold 4 epoch 130
# average train recon loss is: 0.09413934013334777
# average train ortho loss is: 0.010316676774284331
# fold 4 epoch 140
# average train recon loss is: 0.09392146026739016
# average train ortho loss is: 0.01153439637507355
# fold 4 epoch 150
# average train recon loss is: 0.09354092107158325
# average train ortho loss is: 0.011330813842837281
# fold 5 epoch 10
# average train recon loss is: 0.09953153412477628
# average train ortho loss is: 0.019587116895312052
# fold 5 epoch 20
# average train recon loss is: 0.09821425791966876
# average train ortho loss is: 0.020116058879074045
# fold 5 epoch 30
# average train recon loss is: 0.09744629812081124
# average train ortho loss is: 0.01704093963406158
# fold 5 epoch 40
# average train recon loss is: 0.09692931254970588
# average train ortho loss is: 0.014718206829849294
# fold 5 epoch 50
# average train recon loss is: 0.09654175078988474
# average train ortho loss is: 0.01487652314546515
# fold 5 epoch 60
# average train recon loss is: 0.09625792423618279
# average train ortho loss is: 0.014052850944940062
# fold 5 epoch 70
# average train recon loss is: 0.09599016661628035
# average train ortho loss is: 0.013091092923014459
# fold 5 epoch 80
# average train recon loss is: 0.09565476988470276
# average train ortho loss is: 0.013464284979778788
# fold 5 epoch 90
# average train recon loss is: 0.09536257715129533
# average train ortho loss is: 0.014289042024708112
# fold 5 epoch 100
# average train recon loss is: 0.09497426425334203
# average train ortho loss is: 0.013751764759969552
# fold 5 epoch 110
# average train recon loss is: 0.09465613094061912
# average train ortho loss is: 0.013271154368601516
# fold 5 epoch 120
# average train recon loss is: 0.09438970176671262
# average train ortho loss is: 0.012639381813763775
# fold 5 epoch 130
# average train recon loss is: 0.0940020427257321
# average train ortho loss is: 0.010464510989428364
# fold 5 epoch 140
# average train recon loss is: 0.09367292780541257
# average train ortho loss is: 0.011027231662967133
# fold 5 epoch 150
# average train recon loss is: 0.09337399556086613
# average train ortho loss is: 0.010647268000255061
# [I 2024-06-12 20:39:49,682] Trial 0 finished with value: 0.19093408845289053 and parameters: {'lr': 0.00013177038575395484, 'l2_lambda': 6.418758550886033e-08, 'batch_size': 512, 'ortho_multiplier': 0.01, 'epoch': 150, 'l1_s1_out_dim': 64, 'l1_s2_out_dim': 256, 'l1_s12_out_dim': 512, 'l2_s1_out_dim': 512, 'l2_s2_out_dim': 32, 'l2_s12_out_dim': 128, 'l3_s1_out_dim': 1024, 'l3_s2_out_dim': 256, 'l3_s12_out_dim': 256, 'embed_s1_out_dim': 128, 'l1_s1_drop_rate': 0.1, 'l2_s1_drop_rate': 0.4, 'l3_s1_drop_rate': 0.6, 'embed_s1_drop_rate': 0, 'l1_s2_drop_rate': 0.1, 'l2_s2_drop_rate': 0.1, 'l3_s2_drop_rate': 0.1, 'embed_s2_drop_rate': 0.2, 'l1_s12_drop_rate': 0.2, 'l2_s12_drop_rate': 0.4, 'l3_s12_drop_rate': 0.6, 'embed_s12_drop_rate': 0.6, '_embed_s1_out_dim': 256, '_l3_s1_out_dim': 64, '_l2_s1_out_dim': 128, '_embed_s2_out_dim': 1024, '_l3_s2_out_dim': 32, '_l2_s2_out_dim': 32, '_embed_s1_drop_rate': 0.2, '_l3_s1_drop_rate': 0.2, '_l2_s1_drop_rate': 0.6, '_l1_s1_drop_rate': 0.4, '_embed_s2_drop_rate': 0, '_l3_s2_drop_rate': 0.1, '_l2_s2_drop_rate': 0.4, '_l1_s2_drop_rate': 0.1}. Best is trial 0 with value: 0.19093408845289053.
# fold 1 epoch 10
# average train recon loss is: 0.24906843097638884
# average train ortho loss is: 0.004488042645374601
# fold 1 epoch 20
# average train recon loss is: 0.24382020479465627
# average train ortho loss is: 0.0041206839194357645
# fold 1 epoch 30
# average train recon loss is: 0.24068987618929172
# average train ortho loss is: 0.0038482975635568467
# fold 1 epoch 40
# average train recon loss is: 0.23828082623342092
# average train ortho loss is: 0.003548805147534135
# fold 1 epoch 50
# average train recon loss is: 0.23619837262141655
# average train ortho loss is: 0.0033670253958163403
# fold 1 epoch 60
# average train recon loss is: 0.23438362536570018
# average train ortho loss is: 0.0033182407148712348
# fold 1 epoch 70
# average train recon loss is: 0.23278152673314306
# average train ortho loss is: 0.0031999737523090888
# fold 1 epoch 80
# average train recon loss is: 0.23124375522884863
# average train ortho loss is: 0.002988409621944986
# fold 1 epoch 90
# average train recon loss is: 0.22979508563564413
# average train ortho loss is: 0.0028570987564749298
# fold 1 epoch 100
# average train recon loss is: 0.22832450228256163
# average train ortho loss is: 0.0027325564223852116
# fold 1 epoch 110
# average train recon loss is: 0.22719259940430708
# average train ortho loss is: 0.002577353172222441
# fold 1 epoch 120
# average train recon loss is: 0.22631580161250286
# average train ortho loss is: 0.0024708036224213603
# fold 2 epoch 10
# average train recon loss is: 0.24915709076566178
# average train ortho loss is: 0.004379132439900642
# fold 2 epoch 20
# average train recon loss is: 0.24352275018412697
# average train ortho loss is: 0.004144759943794506
# fold 2 epoch 30
# average train recon loss is: 0.24044945609120644
# average train ortho loss is: 0.0038178899173457255
# fold 2 epoch 40
# average train recon loss is: 0.23809900722743077
# average train ortho loss is: 0.003600812394748672
# fold 2 epoch 50
# average train recon loss is: 0.2360981929252337
# average train ortho loss is: 0.003533457437818519
# fold 2 epoch 60
# average train recon loss is: 0.23430939119730035
# average train ortho loss is: 0.003443058165546242
# fold 2 epoch 70
# average train recon loss is: 0.23283240745257133
# average train ortho loss is: 0.003270494252069226
# fold 2 epoch 80
# average train recon loss is: 0.23138828117977125
# average train ortho loss is: 0.0031628996694935915
# fold 2 epoch 90
# average train recon loss is: 0.22999933793454988
# average train ortho loss is: 0.003030066372959185
# fold 2 epoch 100
# average train recon loss is: 0.22871076751453606
# average train ortho loss is: 0.002869829180100972
# fold 2 epoch 110
# average train recon loss is: 0.22739496829619468
# average train ortho loss is: 0.0028121860768006933
# fold 2 epoch 120
# average train recon loss is: 0.22606847036832545
# average train ortho loss is: 0.0025850391038790906
# fold 3 epoch 10
# average train recon loss is: 0.24913366389573868
# average train ortho loss is: 0.004513572773674043
# fold 3 epoch 20
# average train recon loss is: 0.24377811623417683
# average train ortho loss is: 0.004094671479827689
# fold 3 epoch 30
# average train recon loss is: 0.2405459511728965
# average train ortho loss is: 0.003794826224259253
# fold 3 epoch 40
# average train recon loss is: 0.23810770441797488
# average train ortho loss is: 0.0036383005989146532
# fold 3 epoch 50
# average train recon loss is: 0.23616528052166416
# average train ortho loss is: 0.0035099714121559177
# fold 3 epoch 60
# average train recon loss is: 0.23445988020637545
# average train ortho loss is: 0.003377615133588783
# fold 3 epoch 70
# average train recon loss is: 0.23290384045205856
# average train ortho loss is: 0.003340339797810032
# fold 3 epoch 80
# average train recon loss is: 0.23153234585558521
# average train ortho loss is: 0.003177475318250297
# fold 3 epoch 90
# average train recon loss is: 0.23037143771119697
# average train ortho loss is: 0.003038833854587507
# fold 3 epoch 100
# average train recon loss is: 0.2290048822698234
# average train ortho loss is: 0.002976254869455074
# fold 3 epoch 110
# average train recon loss is: 0.2278143782994737
# average train ortho loss is: 0.002767143863015594
# fold 3 epoch 120
# average train recon loss is: 0.22671872701604995
# average train ortho loss is: 0.002665819314982602
# fold 4 epoch 10
# average train recon loss is: 0.24947125981542356
# average train ortho loss is: 0.004543116401927741
# fold 4 epoch 20
# average train recon loss is: 0.243853683950512
# average train ortho loss is: 0.004139588205884191
# fold 4 epoch 30
# average train recon loss is: 0.24061243304647661
# average train ortho loss is: 0.003909321222843984
# fold 4 epoch 40
# average train recon loss is: 0.23834978287190073
# average train ortho loss is: 0.0037311432251870384
# fold 4 epoch 50
# average train recon loss is: 0.2365488834460909
# average train ortho loss is: 0.0035779117290943734
# fold 4 epoch 60
# average train recon loss is: 0.23480602088832456
# average train ortho loss is: 0.0034723411793489336
# fold 4 epoch 70
# average train recon loss is: 0.23311542846168934
# average train ortho loss is: 0.0033508831736432957
# fold 4 epoch 80
# average train recon loss is: 0.23175822940331622
# average train ortho loss is: 0.0031644332359026667
# fold 4 epoch 90
# average train recon loss is: 0.23032886313594036
# average train ortho loss is: 0.0032012541299085736
# fold 4 epoch 100
# average train recon loss is: 0.229117140510591
# average train ortho loss is: 0.002973719221777497
# fold 4 epoch 110
# average train recon loss is: 0.2280668258666992
# average train ortho loss is: 0.0028578725943505514
# fold 4 epoch 120
# average train recon loss is: 0.22671963839351383
# average train ortho loss is: 0.002716494417090795
# fold 5 epoch 10
# average train recon loss is: 0.24938721959806207
# average train ortho loss is: 0.00438407155682012
# fold 5 epoch 20
# average train recon loss is: 0.24353586710416353
# average train ortho loss is: 0.004084547090789546
# fold 5 epoch 30
# average train recon loss is: 0.24084071491075598
# average train ortho loss is: 0.0037990081868442805
# fold 5 epoch 40
# average train recon loss is: 0.2385416214282696
# average train ortho loss is: 0.0036599630222073367
# fold 5 epoch 50
# average train recon loss is: 0.23682956552027062
# average train ortho loss is: 0.003515810883264478
# fold 5 epoch 60
# average train recon loss is: 0.23487308910459181
# average train ortho loss is: 0.0033753844706908517
# fold 5 epoch 70
# average train recon loss is: 0.2331024946576377
# average train ortho loss is: 0.003181298590424069
# fold 5 epoch 80
# average train recon loss is: 0.23161318788560337
# average train ortho loss is: 0.0030341572361845637
# fold 5 epoch 90
# average train recon loss is: 0.2300765051889579
# average train ortho loss is: 0.00284224868219433
# fold 5 epoch 100
# average train recon loss is: 0.22869716041462876
# average train ortho loss is: 0.002599246002559279
# fold 5 epoch 110
# average train recon loss is: 0.22761929075056095
# average train ortho loss is: 0.002572222796570896
# fold 5 epoch 120
# average train recon loss is: 0.22613418859781628
# average train ortho loss is: 0.0023206407484601572
# [I 2024-06-12 20:55:59,974] Trial 1 finished with value: 0.3089770512651439 and parameters: {'lr': 0.00012513509747063593, 'l2_lambda': 1.3663389720616156e-08, 'batch_size': 64, 'ortho_multiplier': 0.1, 'epoch': 120, 'l1_s1_out_dim': 128, 'l1_s2_out_dim': 1024, 'l1_s12_out_dim': 512, 'l2_s1_out_dim': 32, 'l2_s2_out_dim': 256, 'l2_s12_out_dim': 128, 'l3_s1_out_dim': 512, 'l3_s2_out_dim': 512, 'l3_s12_out_dim': 64, 'embed_s1_out_dim': 512, 'l1_s1_drop_rate': 0.6, 'l2_s1_drop_rate': 0.2, 'l3_s1_drop_rate': 0.4, 'embed_s1_drop_rate': 0.2, 'l1_s2_drop_rate': 0.2, 'l2_s2_drop_rate': 0.4, 'l3_s2_drop_rate': 0.2, 'embed_s2_drop_rate': 0.2, 'l1_s12_drop_rate': 0.1, 'l2_s12_drop_rate': 0.4, 'l3_s12_drop_rate': 0.1, 'embed_s12_drop_rate': 0.6, '_embed_s1_out_dim': 1024, '_l3_s1_out_dim': 64, '_l2_s1_out_dim': 32, '_embed_s2_out_dim': 512, '_l3_s2_out_dim': 256, '_l2_s2_out_dim': 512, '_embed_s1_drop_rate': 0.6, '_l3_s1_drop_rate': 0.1, '_l2_s1_drop_rate': 0.4, '_l1_s1_drop_rate': 0.2, '_embed_s2_drop_rate': 0.1, '_l3_s2_drop_rate': 0.1, '_l2_s2_drop_rate': 0.6, '_l1_s2_drop_rate': 0.4}. Best is trial 0 with value: 0.19093408845289053.
# fold 1 epoch 10
# average train recon loss is: 0.24141734454422317
# average train ortho loss is: 0.04831829968855471
# fold 1 epoch 20
# average train recon loss is: 0.23157749255830773
# average train ortho loss is: 0.03968055816873846
# fold 1 epoch 30
# average train recon loss is: 0.22555858181111482
# average train ortho loss is: 0.03694902354204505
# fold 1 epoch 40
# average train recon loss is: 0.2210635021640666
# average train ortho loss is: 0.031275466196706604
# fold 1 epoch 50
# average train recon loss is: 0.21758541761581868
# average train ortho loss is: 0.028619594055239627
# fold 1 epoch 60
# average train recon loss is: 0.21461133757395726
# average train ortho loss is: 0.02932958233805381
# fold 1 epoch 70
# average train recon loss is: 0.21209756699566062
# average train ortho loss is: 0.02814614044572519
# fold 1 epoch 80
# average train recon loss is: 0.20935646280583975
# average train ortho loss is: 0.03021026794880504
# fold 1 epoch 90
# average train recon loss is: 0.20762658139153006
# average train ortho loss is: 0.02784629556424448
# fold 2 epoch 10
# average train recon loss is: 0.24092545928316636
# average train ortho loss is: 0.05184867910760217
# fold 2 epoch 20
# average train recon loss is: 0.2317551880202034
# average train ortho loss is: 0.04564592259698333
# fold 2 epoch 30
# average train recon loss is: 0.22577769067995718
# average train ortho loss is: 0.04282653860467248
# fold 2 epoch 40
# average train recon loss is: 0.2210024558350631
# average train ortho loss is: 0.03665043170482045
# fold 2 epoch 50
# average train recon loss is: 0.21725592752879633
# average train ortho loss is: 0.03425624141134478
# fold 2 epoch 60
# average train recon loss is: 0.21426057616038302
# average train ortho loss is: 0.03118665747063928
# fold 2 epoch 70
# average train recon loss is: 0.21187033713113315
# average train ortho loss is: 0.027814762063605017
# fold 2 epoch 80
# average train recon loss is: 0.20980909419359023
# average train ortho loss is: 0.027601780452488855
# fold 2 epoch 90
# average train recon loss is: 0.20758704181495571
# average train ortho loss is: 0.028936196121710615
# fold 3 epoch 10
# average train recon loss is: 0.24153878040393525
# average train ortho loss is: 0.04468768710371839
# fold 3 epoch 20
# average train recon loss is: 0.23217774873996877
# average train ortho loss is: 0.04533049332048105
# fold 3 epoch 30
# average train recon loss is: 0.22616131754599855
# average train ortho loss is: 0.035504062105921025
# fold 3 epoch 40
# average train recon loss is: 0.22126643847222108
# average train ortho loss is: 0.03278691389570675
# fold 3 epoch 50
# average train recon loss is: 0.21768862033987643
# average train ortho loss is: 0.034378592439276406
# fold 3 epoch 60
# average train recon loss is: 0.21472794680415835
# average train ortho loss is: 0.030481502301523376
# fold 3 epoch 70
# average train recon loss is: 0.21212362185681713
# average train ortho loss is: 0.03033083193471741
# fold 3 epoch 80
# average train recon loss is: 0.2104251278992976
# average train ortho loss is: 0.0343449394074444
# fold 3 epoch 90
# average train recon loss is: 0.20833762420271232
# average train ortho loss is: 0.03086090945798483
# fold 4 epoch 10
# average train recon loss is: 0.24163277518300333
# average train ortho loss is: 0.04941216911730906
# fold 4 epoch 20
# average train recon loss is: 0.23207685159340063
# average train ortho loss is: 0.04743220237508478
# fold 4 epoch 30
# average train recon loss is: 0.2264925274390057
# average train ortho loss is: 0.037729675001679105
# fold 4 epoch 40
# average train recon loss is: 0.2218582887529828
# average train ortho loss is: 0.035129301218806946
# fold 4 epoch 50
# average train recon loss is: 0.21819514510023044
# average train ortho loss is: 0.035072445669932346
# fold 4 epoch 60
# average train recon loss is: 0.2150673958048162
# average train ortho loss is: 0.033508952990735426
# fold 4 epoch 70
# average train recon loss is: 0.21266882190145708
# average train ortho loss is: 0.03158032495107611
# fold 4 epoch 80
# average train recon loss is: 0.21043588327064675
# average train ortho loss is: 0.03377980846740212
# fold 4 epoch 90
# average train recon loss is: 0.20879856173463446
# average train ortho loss is: 0.03498027135138731
# fold 5 epoch 10
# average train recon loss is: 0.24154084263039274
# average train ortho loss is: 0.042368988229279536
# fold 5 epoch 20
# average train recon loss is: 0.23186898709938278
# average train ortho loss is: 0.04457296705166233
# fold 5 epoch 30
# average train recon loss is: 0.22547689249682984
# average train ortho loss is: 0.043569371453097035
# fold 5 epoch 40
# average train recon loss is: 0.2210775593850126
# average train ortho loss is: 0.03655958036116533
# fold 5 epoch 50
# average train recon loss is: 0.2171107096018201
# average train ortho loss is: 0.034652699993605596
# fold 5 epoch 60
# average train recon loss is: 0.21413948304677088
# average train ortho loss is: 0.03767526528508368
# fold 5 epoch 70
# average train recon loss is: 0.2117522799450418
# average train ortho loss is: 0.031958794215052426
# fold 5 epoch 80
# average train recon loss is: 0.20961056664635905
# average train ortho loss is: 0.034661443337150245
# fold 5 epoch 90
# average train recon loss is: 0.2079276552168422
# average train ortho loss is: 0.03229310032117327
# [I 2024-06-12 21:07:43,320] Trial 2 finished with value: 0.2769714266351615 and parameters: {'lr': 0.0006832903049538647, 'l2_lambda': 2.4679207914351944e-07, 'batch_size': 64, 'ortho_multiplier': 0.001, 'epoch': 90, 'l1_s1_out_dim': 256, 'l1_s2_out_dim': 1024, 'l1_s12_out_dim': 64, 'l2_s1_out_dim': 256, 'l2_s2_out_dim': 128, 'l2_s12_out_dim': 32, 'l3_s1_out_dim': 64, 'l3_s2_out_dim': 128, 'l3_s12_out_dim': 128, 'embed_s1_out_dim': 64, 'l1_s1_drop_rate': 0.2, 'l2_s1_drop_rate': 0.6, 'l3_s1_drop_rate': 0.4, 'embed_s1_drop_rate': 0, 'l1_s2_drop_rate': 0.6, 'l2_s2_drop_rate': 0.4, 'l3_s2_drop_rate': 0.6, 'embed_s2_drop_rate': 0.6, 'l1_s12_drop_rate': 0.4, 'l2_s12_drop_rate': 0.1, 'l3_s12_drop_rate': 0.4, 'embed_s12_drop_rate': 0.2, '_embed_s1_out_dim': 32, '_l3_s1_out_dim': 1024, '_l2_s1_out_dim': 32, '_embed_s2_out_dim': 256, '_l3_s2_out_dim': 32, '_l2_s2_out_dim': 32, '_embed_s1_drop_rate': 0.6, '_l3_s1_drop_rate': 0.6, '_l2_s1_drop_rate': 0.4, '_l1_s1_drop_rate': 0.4, '_embed_s2_drop_rate': 0.4, '_l3_s2_drop_rate': 0, '_l2_s2_drop_rate': 0.6, '_l1_s2_drop_rate': 0.1}. Best is trial 0 with value: 0.19093408845289053.
# fold 1 epoch 10
# average train recon loss is: 0.23833341319191906
# average train ortho loss is: 0.009993672844755101
# fold 1 epoch 20
# average train recon loss is: 0.23144263822164496
# average train ortho loss is: 0.004382684053736252
# fold 1 epoch 30
# average train recon loss is: 0.22758061397025775
# average train ortho loss is: 0.0023342968903824874
# fold 1 epoch 40
# average train recon loss is: 0.22496234063822854
# average train ortho loss is: 0.001463254662737188
# fold 1 epoch 50
# average train recon loss is: 0.22303428091264668
# average train ortho loss is: 0.0010908956838202777
# fold 1 epoch 60
# average train recon loss is: 0.22153538580220114
# average train ortho loss is: 0.000817578583644025
# fold 2 epoch 10
# average train recon loss is: 0.237914896210866
# average train ortho loss is: 0.010450706097870192
# fold 2 epoch 20
# average train recon loss is: 0.23146067104579016
# average train ortho loss is: 0.004695975007372421
# fold 2 epoch 30
# average train recon loss is: 0.22763618485199358
# average train ortho loss is: 0.0024621642284313504
# fold 2 epoch 40
# average train recon loss is: 0.2250599873115827
# average train ortho loss is: 0.001687671287788008
# fold 2 epoch 50
# average train recon loss is: 0.2230071199488939
# average train ortho loss is: 0.0011894220977273445
# fold 2 epoch 60
# average train recon loss is: 0.22157276903735046
# average train ortho loss is: 0.0010866375460784306
# fold 3 epoch 10
# average train recon loss is: 0.23764206475293786
# average train ortho loss is: 0.00983921187193324
# fold 3 epoch 20
# average train recon loss is: 0.23130461800547325
# average train ortho loss is: 0.004615320383754235
# fold 3 epoch 30
# average train recon loss is: 0.2275283574060416
# average train ortho loss is: 0.002364462102806219
# fold 3 epoch 40
# average train recon loss is: 0.22520322360753015
# average train ortho loss is: 0.002256338915565523
# fold 3 epoch 50
# average train recon loss is: 0.22311918426258295
# average train ortho loss is: 0.0012268593152946008
# fold 3 epoch 60
# average train recon loss is: 0.22169482578293548
# average train ortho loss is: 0.0011125412040923928
# fold 4 epoch 10
# average train recon loss is: 0.2379584699495068
# average train ortho loss is: 0.010266791552180526
# fold 4 epoch 20
# average train recon loss is: 0.2314554062847313
# average train ortho loss is: 0.004652069752186412
# fold 4 epoch 30
# average train recon loss is: 0.22780112661577168
# average train ortho loss is: 0.0026371374102815925
# fold 4 epoch 40
# average train recon loss is: 0.2251585756884459
# average train ortho loss is: 0.0015062796458539603
# fold 4 epoch 50
# average train recon loss is: 0.2233818293615365
# average train ortho loss is: 0.0010715034903342755
# fold 4 epoch 60
# average train recon loss is: 0.2219115612397134
# average train ortho loss is: 0.0008308243162337706
# fold 5 epoch 10
# average train recon loss is: 0.23735646898531196
# average train ortho loss is: 0.011352104137972446
# fold 5 epoch 20
# average train recon loss is: 0.2307690720893069
# average train ortho loss is: 0.0052910796475649675
# fold 5 epoch 30
# average train recon loss is: 0.22687508908402562
# average train ortho loss is: 0.002835051589536428
# fold 5 epoch 40
# average train recon loss is: 0.22441711633101755
# average train ortho loss is: 0.0018165053513187629
# fold 5 epoch 50
# average train recon loss is: 0.2224207681955701
# average train ortho loss is: 0.0010055440749013704
# fold 5 epoch 60
# average train recon loss is: 0.22097079171783549
# average train ortho loss is: 0.0007926963525123421
# [I 2024-06-12 21:16:15,203] Trial 3 finished with value: 0.2856334885079059 and parameters: {'lr': 0.0007053486704323371, 'l2_lambda': 3.249814866499862e-08, 'batch_size': 64, 'ortho_multiplier': 1.0, 'epoch': 60, 'l1_s1_out_dim': 64, 'l1_s2_out_dim': 32, 'l1_s12_out_dim': 512, 'l2_s1_out_dim': 256, 'l2_s2_out_dim': 1024, 'l2_s12_out_dim': 512, 'l3_s1_out_dim': 32, 'l3_s2_out_dim': 128, 'l3_s12_out_dim': 256, 'embed_s1_out_dim': 128, 'l1_s1_drop_rate': 0.1, 'l2_s1_drop_rate': 0, 'l3_s1_drop_rate': 0, 'embed_s1_drop_rate': 0, 'l1_s2_drop_rate': 0.4, 'l2_s2_drop_rate': 0.1, 'l3_s2_drop_rate': 0, 'embed_s2_drop_rate': 0, 'l1_s12_drop_rate': 0.4, 'l2_s12_drop_rate': 0.1, 'l3_s12_drop_rate': 0.2, 'embed_s12_drop_rate': 0, '_embed_s1_out_dim': 512, '_l3_s1_out_dim': 512, '_l2_s1_out_dim': 512, '_embed_s2_out_dim': 256, '_l3_s2_out_dim': 256, '_l2_s2_out_dim': 64, '_embed_s1_drop_rate': 0.1, '_l3_s1_drop_rate': 0.6, '_l2_s1_drop_rate': 0.4, '_l1_s1_drop_rate': 0.6, '_embed_s2_drop_rate': 0.4, '_l3_s2_drop_rate': 0.6, '_l2_s2_drop_rate': 0, '_l1_s2_drop_rate': 0.4}. Best is trial 0 with value: 0.19093408845289053.
# fold 1 epoch 10
# average train recon loss is: 0.23989737762068106
# average train ortho loss is: 0.0020922688634824552
# fold 1 epoch 20
# average train recon loss is: 0.23469830117963847
# average train ortho loss is: 0.0017928335519515322
# fold 1 epoch 30
# average train recon loss is: 0.23101919086408415
# average train ortho loss is: 0.001633294151168488
# fold 1 epoch 40
# average train recon loss is: 0.22801229006076956
# average train ortho loss is: 0.0014454643160229448
# fold 1 epoch 50
# average train recon loss is: 0.22571621579605167
# average train ortho loss is: 0.0013329850268164439
# fold 1 epoch 60
# average train recon loss is: 0.2238982252496057
# average train ortho loss is: 0.0012133967022267345
# fold 1 epoch 70
# average train recon loss is: 0.22264423130945182
# average train ortho loss is: 0.00129196305591691
# fold 1 epoch 80
# average train recon loss is: 0.22162703669719616
# average train ortho loss is: 0.0013333043044581074
# fold 1 epoch 90
# average train recon loss is: 0.2208154279317816
# average train ortho loss is: 0.0018880747165141245
# fold 1 epoch 100
# average train recon loss is: 0.2199588456413237
# average train ortho loss is: 0.0014490283620407392
# fold 1 epoch 110
# average train recon loss is: 0.2193565488360417
# average train ortho loss is: 0.0013401685150098602
# fold 1 epoch 120
# average train recon loss is: 0.21893049184248536
# average train ortho loss is: 0.0013906060371189437
# fold 1 epoch 130
# average train recon loss is: 0.2185546396167707
# average train ortho loss is: 0.0013505306546907545
# fold 1 epoch 140
# average train recon loss is: 0.21795640091516982
# average train ortho loss is: 0.0011893607956595003
# fold 1 epoch 150
# average train recon loss is: 0.21774632362142268
# average train ortho loss is: 0.0013994284005344661
# fold 2 epoch 10
# average train recon loss is: 0.23998295851831156
# average train ortho loss is: 0.0020231743923789787
# fold 2 epoch 20
# average train recon loss is: 0.23475196790495678
# average train ortho loss is: 0.001751964137145166
# fold 2 epoch 30
# average train recon loss is: 0.23129373574356654
# average train ortho loss is: 0.0016267899626468516
# fold 2 epoch 40
# average train recon loss is: 0.2286875664938444
# average train ortho loss is: 0.0015045844143155229
# fold 2 epoch 50
# average train recon loss is: 0.22664369160161357
# average train ortho loss is: 0.0013784595363808476
# fold 2 epoch 60
# average train recon loss is: 0.2246451286092463
# average train ortho loss is: 0.001217959864867781
# fold 2 epoch 70
# average train recon loss is: 0.22307502874270643
# average train ortho loss is: 0.0011526728617845719
# fold 2 epoch 80
# average train recon loss is: 0.22183710122208217
# average train ortho loss is: 0.0010328485034250315
# fold 2 epoch 90
# average train recon loss is: 0.2210270574402111
# average train ortho loss is: 0.00115616693469271
# fold 2 epoch 100
# average train recon loss is: 0.22017903427698624
# average train ortho loss is: 0.0011460086634717725
# fold 2 epoch 110
# average train recon loss is: 0.21955047032823125
# average train ortho loss is: 0.0010199182171951279
# fold 2 epoch 120
# average train recon loss is: 0.2189922109308602
# average train ortho loss is: 0.001108610729792128
# fold 2 epoch 130
# average train recon loss is: 0.21868058128835766
# average train ortho loss is: 0.0011356872588271377
# fold 2 epoch 140
# average train recon loss is: 0.21813006221499903
# average train ortho loss is: 0.00083282247310403
# fold 2 epoch 150
# average train recon loss is: 0.21793849418352837
# average train ortho loss is: 0.0010280538927062285
# fold 3 epoch 10
# average train recon loss is: 0.2395407960005884
# average train ortho loss is: 0.0020344370391578354
# fold 3 epoch 20
# average train recon loss is: 0.23455782774602021
# average train ortho loss is: 0.0017258943311838923
# fold 3 epoch 30
# average train recon loss is: 0.23119012042568318
# average train ortho loss is: 0.0015017456651731514
# fold 3 epoch 40
# average train recon loss is: 0.22834473454303822
# average train ortho loss is: 0.0013751199118263054
# fold 3 epoch 50
# average train recon loss is: 0.22592499944455455
# average train ortho loss is: 0.0011830738679385086
# fold 3 epoch 60
# average train recon loss is: 0.2238615977714251
# average train ortho loss is: 0.0011072036081527566
# fold 3 epoch 70
# average train recon loss is: 0.22271880385267187
# average train ortho loss is: 0.0013596873714834077
# fold 3 epoch 80
# average train recon loss is: 0.22153905764783277
# average train ortho loss is: 0.0012034365198103454
# fold 3 epoch 90
# average train recon loss is: 0.22054568813435702
# average train ortho loss is: 0.0010566256161015403
# fold 3 epoch 100
# average train recon loss is: 0.22003663035117432
# average train ortho loss is: 0.0013898041520158616
# fold 3 epoch 110
# average train recon loss is: 0.2193658357883597
# average train ortho loss is: 0.0011080287147515987
# fold 3 epoch 120
# average train recon loss is: 0.21873056499529084
# average train ortho loss is: 0.0010032053865398822
# fold 3 epoch 130
# average train recon loss is: 0.2187603794879993
# average train ortho loss is: 0.001148943936600346
# fold 3 epoch 140
# average train recon loss is: 0.2177750439823422
# average train ortho loss is: 0.000993278089552245
# fold 3 epoch 150
# average train recon loss is: 0.21755754399000352
# average train ortho loss is: 0.0010217914490270813
# fold 4 epoch 10
# average train recon loss is: 0.23985783325578378
# average train ortho loss is: 0.001969234140348235
# fold 4 epoch 20
# average train recon loss is: 0.23485956630946203
# average train ortho loss is: 0.0017376205911197424
# fold 4 epoch 30
# average train recon loss is: 0.2313672285199664
# average train ortho loss is: 0.0015288318051453914
# fold 4 epoch 40
# average train recon loss is: 0.22852380345556028
# average train ortho loss is: 0.0014609132569953487
# fold 4 epoch 50
# average train recon loss is: 0.22621529152203804
# average train ortho loss is: 0.0012777552632108394
# fold 4 epoch 60
# average train recon loss is: 0.22423286677404428
# average train ortho loss is: 0.0011647208496367084
# fold 4 epoch 70
# average train recon loss is: 0.2227286805667638
# average train ortho loss is: 0.0010578277220785867
# fold 4 epoch 80
# average train recon loss is: 0.22168998558650954
# average train ortho loss is: 0.001103662799217711
# fold 4 epoch 90
# average train recon loss is: 0.22080781370027294
# average train ortho loss is: 0.0010987812536281522
# fold 4 epoch 100
# average train recon loss is: 0.2200062021550773
# average train ortho loss is: 0.001037875843472062
# fold 4 epoch 110
# average train recon loss is: 0.2196408922203415
# average train ortho loss is: 0.0013559493497325786
# fold 4 epoch 120
# average train recon loss is: 0.21909002758967827
# average train ortho loss is: 0.0012276414360960159
# fold 4 epoch 130
# average train recon loss is: 0.21879079252107372
# average train ortho loss is: 0.0011575657734062882
# fold 4 epoch 140
# average train recon loss is: 0.21849481271400611
# average train ortho loss is: 0.0012319501068552168
# fold 4 epoch 150
# average train recon loss is: 0.21783031639194889
# average train ortho loss is: 0.0010306401513361034
# fold 5 epoch 10
# average train recon loss is: 0.23937808949014414
# average train ortho loss is: 0.0020357192085937513
# fold 5 epoch 20
# average train recon loss is: 0.23448830224997225
# average train ortho loss is: 0.0018516409157909278
# fold 5 epoch 30
# average train recon loss is: 0.23096573631899014
# average train ortho loss is: 0.001557626247555516
# fold 5 epoch 40
# average train recon loss is: 0.22794938246940688
# average train ortho loss is: 0.0014425848476763154
# fold 5 epoch 50
# average train recon loss is: 0.22566502708256445
# average train ortho loss is: 0.0013607232628957086
# fold 5 epoch 60
# average train recon loss is: 0.22354348048717282
# average train ortho loss is: 0.00122139211058816
# fold 5 epoch 70
# average train recon loss is: 0.22205443685270074
# average train ortho loss is: 0.0010473640716594198
# fold 5 epoch 80
# average train recon loss is: 0.2211052175349615
# average train ortho loss is: 0.0013030561490800468
# fold 5 epoch 90
# average train recon loss is: 0.22031050461989182
# average train ortho loss is: 0.0010718311896441772
# fold 5 epoch 100
# average train recon loss is: 0.21990981389048905
# average train ortho loss is: 0.0016678629200095716
# fold 5 epoch 110
# average train recon loss is: 0.21891740094060483
# average train ortho loss is: 0.001434449374326894
# fold 5 epoch 120
# average train recon loss is: 0.21827504626883312
# average train ortho loss is: 0.001233957446239465
# fold 5 epoch 130
# average train recon loss is: 0.21796535249537846
# average train ortho loss is: 0.0011625253723118218
# fold 5 epoch 140
# average train recon loss is: 0.21738850711580104
# average train ortho loss is: 0.001062224818437195
# fold 5 epoch 150
# average train recon loss is: 0.21706031158217617
# average train ortho loss is: 0.0010805467741694737
# [I 2024-06-12 21:40:40,892] Trial 4 finished with value: 0.27127637905499896 and parameters: {'lr': 0.000497363327637842, 'l2_lambda': 6.791386098586477e-07, 'batch_size': 64, 'ortho_multiplier': 0.1, 'epoch': 150, 'l1_s1_out_dim': 512, 'l1_s2_out_dim': 1024, 'l1_s12_out_dim': 64, 'l2_s1_out_dim': 32, 'l2_s2_out_dim': 32, 'l2_s12_out_dim': 32, 'l3_s1_out_dim': 512, 'l3_s2_out_dim': 256, 'l3_s12_out_dim': 512, 'embed_s1_out_dim': 1024, 'l1_s1_drop_rate': 0.2, 'l2_s1_drop_rate': 0.1, 'l3_s1_drop_rate': 0.6, 'embed_s1_drop_rate': 0.1, 'l1_s2_drop_rate': 0.4, 'l2_s2_drop_rate': 0.6, 'l3_s2_drop_rate': 0.2, 'embed_s2_drop_rate': 0.1, 'l1_s12_drop_rate': 0, 'l2_s12_drop_rate': 0.6, 'l3_s12_drop_rate': 0, 'embed_s12_drop_rate': 0.2, '_embed_s1_out_dim': 1024, '_l3_s1_out_dim': 1024, '_l2_s1_out_dim': 64, '_embed_s2_out_dim': 32, '_l3_s2_out_dim': 512, '_l2_s2_out_dim': 256, '_embed_s1_drop_rate': 0, '_l3_s1_drop_rate': 0.2, '_l2_s1_drop_rate': 0.1, '_l1_s1_drop_rate': 0.4, '_embed_s2_drop_rate': 0.1, '_l3_s2_drop_rate': 0.1, '_l2_s2_drop_rate': 0.1, '_l1_s2_drop_rate': 0.6}. Best is trial 0 with value: 0.19093408845289053.
# fold 1 epoch 10
# average train recon loss is: 0.3590439608905106
# average train ortho loss is: 0.014012546232554704
# fold 1 epoch 20
# average train recon loss is: 0.34861007834079377
# average train ortho loss is: 0.011702704529383193
# fold 1 epoch 30
# average train recon loss is: 0.3436689049628988
# average train ortho loss is: 0.009563226230972482
# fold 1 epoch 40
# average train recon loss is: 0.34008755185115286
# average train ortho loss is: 0.007778655310554983
# fold 1 epoch 50
# average train recon loss is: 0.3376228883176668
# average train ortho loss is: 0.006316335754913267
# fold 1 epoch 60
# average train recon loss is: 0.3356355635192105
# average train ortho loss is: 0.005634367883704198
# fold 1 epoch 70
# average train recon loss is: 0.3340242501582062
# average train ortho loss is: 0.004993660822822459
# fold 1 epoch 80
# average train recon loss is: 0.33219971038307605
# average train ortho loss is: 0.00393080482547752
# fold 1 epoch 90
# average train recon loss is: 0.3305388654126283
# average train ortho loss is: 0.003146184002006403
# fold 1 epoch 100
# average train recon loss is: 0.32906140802295636
# average train ortho loss is: 0.0025842880978245116
# fold 1 epoch 110
# average train recon loss is: 0.32771918324745847
# average train ortho loss is: 0.0027486017371321325
# fold 1 epoch 120
# average train recon loss is: 0.32588139378376085
# average train ortho loss is: 0.001863883049168846
# fold 2 epoch 10
# average train recon loss is: 0.35847971808461465
# average train ortho loss is: 0.014423223968330288
# fold 2 epoch 20
# average train recon loss is: 0.34791353058116703
# average train ortho loss is: 0.012267022639138928
# fold 2 epoch 30
# average train recon loss is: 0.34290803127209013
# average train ortho loss is: 0.009992151342675277
# fold 2 epoch 40
# average train recon loss is: 0.3400525939015664
# average train ortho loss is: 0.00762400804204422
# fold 2 epoch 50
# average train recon loss is: 0.3376801143630279
# average train ortho loss is: 0.006086623319522108
# fold 2 epoch 60
# average train recon loss is: 0.3356232687020402
# average train ortho loss is: 0.005011989509834904
# fold 2 epoch 70
# average train recon loss is: 0.3339308024450326
# average train ortho loss is: 0.004178795068832621
# fold 2 epoch 80
# average train recon loss is: 0.3321287693837697
# average train ortho loss is: 0.0037174317876664167
# fold 2 epoch 90
# average train recon loss is: 0.33028754629350604
# average train ortho loss is: 0.0028272002436625907
# fold 2 epoch 100
# average train recon loss is: 0.32878599525994334
# average train ortho loss is: 0.00262751961165891
# fold 2 epoch 110
# average train recon loss is: 0.3272468862174445
# average train ortho loss is: 0.0025945903585296295
# fold 2 epoch 120
# average train recon loss is: 0.3260414634289602
# average train ortho loss is: 0.0021327627892898217
# fold 3 epoch 10
# average train recon loss is: 0.3585488890005455
# average train ortho loss is: 0.014801521056865549
# fold 3 epoch 20
# average train recon loss is: 0.3482739628109473
# average train ortho loss is: 0.012022426961356128
# fold 3 epoch 30
# average train recon loss is: 0.34372511668185307
# average train ortho loss is: 0.010077303872447632
# fold 3 epoch 40
# average train recon loss is: 0.34017822153897465
# average train ortho loss is: 0.007827755017011235
# fold 3 epoch 50
# average train recon loss is: 0.3380083263668555
# average train ortho loss is: 0.007044461781010967
# fold 3 epoch 60
# average train recon loss is: 0.3357066357983705
# average train ortho loss is: 0.0056865415438448535
# fold 3 epoch 70
# average train recon loss is: 0.33361608992061853
# average train ortho loss is: 0.0048772604270959
# fold 3 epoch 80
# average train recon loss is: 0.33199118929428034
# average train ortho loss is: 0.004505161984695052
# fold 3 epoch 90
# average train recon loss is: 0.33041190063604253
# average train ortho loss is: 0.003952587554893733
# fold 3 epoch 100
# average train recon loss is: 0.32904353520860236
# average train ortho loss is: 0.003533249999938151
# fold 3 epoch 110
# average train recon loss is: 0.3274815930482234
# average train ortho loss is: 0.002905084647892908
# fold 3 epoch 120
# average train recon loss is: 0.3261282222540309
# average train ortho loss is: 0.0025685608948125003
# fold 4 epoch 10
# average train recon loss is: 0.35916874857627196
# average train ortho loss is: 0.014672271938503536
# fold 4 epoch 20
# average train recon loss is: 0.34885839318630585
# average train ortho loss is: 0.012063827823894294
# fold 4 epoch 30
# average train recon loss is: 0.34389138840232436
# average train ortho loss is: 0.010259864856508486
# fold 4 epoch 40
# average train recon loss is: 0.3406902241407578
# average train ortho loss is: 0.008154169398371644
# fold 4 epoch 50
# average train recon loss is: 0.3381447871858605
# average train ortho loss is: 0.006764624919352671
# fold 4 epoch 60
# average train recon loss is: 0.3362288846131648
# average train ortho loss is: 0.006045550083016751
# fold 4 epoch 70
# average train recon loss is: 0.33439929435442683
# average train ortho loss is: 0.005076962484974243
# fold 4 epoch 80
# average train recon loss is: 0.3326909524127529
# average train ortho loss is: 0.004283428909140152
# fold 4 epoch 90
# average train recon loss is: 0.3310678693539927
# average train ortho loss is: 0.0038455927783475263
# fold 4 epoch 100
# average train recon loss is: 0.3295881127712617
# average train ortho loss is: 0.0035701062951127853
# fold 4 epoch 110
# average train recon loss is: 0.32809911352819976
# average train ortho loss is: 0.0032068815503160323
# fold 4 epoch 120
# average train recon loss is: 0.32691762158062665
# average train ortho loss is: 0.002628283763779756
# fold 5 epoch 10
# average train recon loss is: 0.35717987336442625
# average train ortho loss is: 0.014517347574433355
# fold 5 epoch 20
# average train recon loss is: 0.3480313498040904
# average train ortho loss is: 0.011604726189953028
# fold 5 epoch 30
# average train recon loss is: 0.34356658833481396
# average train ortho loss is: 0.008743457433870404
# fold 5 epoch 40
# average train recon loss is: 0.34062935995019
# average train ortho loss is: 0.0072325680928186425
# fold 5 epoch 50
# average train recon loss is: 0.33831649639933403
# average train ortho loss is: 0.0057947656457440115
# fold 5 epoch 60
# average train recon loss is: 0.3363198883158706
# average train ortho loss is: 0.005267069011577794
# fold 5 epoch 70
# average train recon loss is: 0.33422780754574166
# average train ortho loss is: 0.003995768965710964
# fold 5 epoch 80
# average train recon loss is: 0.33246592454687013
# average train ortho loss is: 0.003431151876456562
# fold 5 epoch 90
# average train recon loss is: 0.3306890068245572
# average train ortho loss is: 0.0029392421532135745
# fold 5 epoch 100
# average train recon loss is: 0.3292104213134102
# average train ortho loss is: 0.0027294706360103693
# fold 5 epoch 110
# average train recon loss is: 0.32763746311034647
# average train ortho loss is: 0.00221506480351838
# fold 5 epoch 120
# average train recon loss is: 0.3262004230333411
# average train ortho loss is: 0.0018395080330803441
# [I 2024-06-12 22:06:51,372] Trial 5 finished with value: 0.8506608004281014 and parameters: {'lr': 5.966099647592775e-05, 'l2_lambda': 9.438779385088106e-08, 'batch_size': 32, 'ortho_multiplier': 1.0, 'epoch': 120, 'l1_s1_out_dim': 64, 'l1_s2_out_dim': 1024, 'l1_s12_out_dim': 128, 'l2_s1_out_dim': 256, 'l2_s2_out_dim': 512, 'l2_s12_out_dim': 512, 'l3_s1_out_dim': 32, 'l3_s2_out_dim': 1024, 'l3_s12_out_dim': 1024, 'embed_s1_out_dim': 128, 'l1_s1_drop_rate': 0, 'l2_s1_drop_rate': 0.1, 'l3_s1_drop_rate': 0.1, 'embed_s1_drop_rate': 0.1, 'l1_s2_drop_rate': 0, 'l2_s2_drop_rate': 0.2, 'l3_s2_drop_rate': 0.2, 'embed_s2_drop_rate': 0.4, 'l1_s12_drop_rate': 0, 'l2_s12_drop_rate': 0.4, 'l3_s12_drop_rate': 0.4, 'embed_s12_drop_rate': 0.1, '_embed_s1_out_dim': 256, '_l3_s1_out_dim': 256, '_l2_s1_out_dim': 128, '_embed_s2_out_dim': 512, '_l3_s2_out_dim': 32, '_l2_s2_out_dim': 128, '_embed_s1_drop_rate': 0.6, '_l3_s1_drop_rate': 0, '_l2_s1_drop_rate': 0.2, '_l1_s1_drop_rate': 0.4, '_embed_s2_drop_rate': 0, '_l3_s2_drop_rate': 0.2, '_l2_s2_drop_rate': 0, '_l1_s2_drop_rate': 0.6}. Best is trial 0 with value: 0.19093408845289053.
# fold 1 epoch 10
# average train recon loss is: 0.09640303097010657
# average train ortho loss is: 0.0045203618424706875
# fold 1 epoch 20
# average train recon loss is: 0.09481774174518665
# average train ortho loss is: 0.0038398865625948087
# fold 1 epoch 30
# average train recon loss is: 0.09385470785356466
# average train ortho loss is: 0.0035271246064158164
# fold 1 epoch 40
# average train recon loss is: 0.09309402210443089
# average train ortho loss is: 0.003128245136229064
# fold 1 epoch 50
# average train recon loss is: 0.09251448818829269
# average train ortho loss is: 0.0028878127680662786
# fold 1 epoch 60
# average train recon loss is: 0.09199360484358655
# average train ortho loss is: 0.002732453535790224
# fold 1 epoch 70
# average train recon loss is: 0.09167778142825331
# average train ortho loss is: 0.0024985721171151645
# fold 1 epoch 80
# average train recon loss is: 0.09130665607532198
# average train ortho loss is: 0.002337636783033235
# fold 1 epoch 90
# average train recon loss is: 0.09095735110997157
# average train ortho loss is: 0.0024389415605297646
# fold 1 epoch 100
# average train recon loss is: 0.09066249895295339
# average train ortho loss is: 0.0024091197107626305
# fold 1 epoch 110
# average train recon loss is: 0.09037300014096823
# average train ortho loss is: 0.002388559524983043
# fold 1 epoch 120
# ...
# fold 1 epoch 20
# average train recon loss is: 0.13284275980674073
# average train ortho loss is: 0.013742773502940413
# fold 1 epoch 30
# average train recon loss is: 0.12733422921791238
# average train ortho loss is: 0.0097755298704283
# fold 1 epoch 40
# average train recon loss is: 0.12582757622627036
# average train ortho loss is: 0.011905364561280446
# fold 1 epoch 50
# average train recon loss is: 0.12406626984664088
# average train ortho loss is: 0.010729611468614396
# fold 1 epoch 60
# average train recon loss is: 0.12350159170238542
# average train ortho loss is: 0.015389962525547298
# fold 1 epoch 70
# average train recon loss is: 0.12296082883699169
# average train ortho loss is: 0.018339390235964724
# fold 1 epoch 80
# average train recon loss is: 0.12306919895954212
# average train ortho loss is: 0.02947263129086674
# fold 1 epoch 90
# average train recon loss is: 0.1217741379678
# average train ortho loss is: 0.017481026489864333
# fold 1 epoch 100
# average train recon loss is: 0.12065725685662305
# average train ortho loss is: 0.014822574439906675
# fold 1 epoch 110
# average train recon loss is: 0.12014901388639186
# average train ortho loss is: 0.01604195199750956
# fold 1 epoch 120
# average train recon loss is: 0.11975479844225001
# average train ortho loss is: 0.014022996884509609
# fold 2 epoch 10
# average train recon loss is: 0.14552784365091365
# average train ortho loss is: 0.020772215112981437
# fold 2 epoch 20
# average train recon loss is: 0.13312128537868356
# average train ortho loss is: 0.01205846981523426
# fold 2 epoch 30
# average train recon loss is: 0.1274180767426431
# average train ortho loss is: 0.010384727372285213
# fold 2 epoch 40
# average train recon loss is: 0.12480244337265461
# average train ortho loss is: 0.010355830117748372
# fold 2 epoch 50
# average train recon loss is: 0.12438335179285026
# average train ortho loss is: 0.019514378892826735
# fold 2 epoch 60
# average train recon loss is: 0.1224244217493544
# average train ortho loss is: 0.010363004097878683
# fold 2 epoch 70
# average train recon loss is: 0.12162671986982912
# average train ortho loss is: 0.011925355210962654
# fold 2 epoch 80
# average train recon loss is: 0.12108912288394433
# average train ortho loss is: 0.009332441784846733
# fold 2 epoch 90
# average train recon loss is: 0.12048629696897882
# average train ortho loss is: 0.008996754011848481
# fold 2 epoch 100
# average train recon loss is: 0.11976578285504584
# average train ortho loss is: 0.008245203759380964
# fold 2 epoch 110
# average train recon loss is: 0.1192024294801337
# average train ortho loss is: 0.008775133767387358
# fold 2 epoch 120
# average train recon loss is: 0.11907317428908089
# average train ortho loss is: 0.008368881352276982
# fold 3 epoch 10
# average train recon loss is: 0.14566217047400057
# average train ortho loss is: 0.019257584575828646
# fold 3 epoch 20
# average train recon loss is: 0.13288446530138598
# average train ortho loss is: 0.012451865732919221
# fold 3 epoch 30
# average train recon loss is: 0.1285359466425046
# average train ortho loss is: 0.013470571859112344
# fold 3 epoch 40
# average train recon loss is: 0.12606308270697814
# average train ortho loss is: 0.01669815165228425
# fold 3 epoch 50
# average train recon loss is: 0.12471000160632273
# average train ortho loss is: 0.016727955820171406
# fold 3 epoch 60
# average train recon loss is: 0.12326542842338274
# average train ortho loss is: 0.011905504869117896
# fold 3 epoch 70
# average train recon loss is: 0.12354022947814175
# average train ortho loss is: 0.019005890171896963
# fold 3 epoch 80
# average train recon loss is: 0.1225137670668598
# average train ortho loss is: 0.015108947474587412
# fold 3 epoch 90
# average train recon loss is: 0.12148628314668664
# average train ortho loss is: 0.012873369729668526
# fold 3 epoch 100
# average train recon loss is: 0.1208680476104864
# average train ortho loss is: 0.011129737473930774
# fold 3 epoch 110
# average train recon loss is: 0.12088952084465505
# average train ortho loss is: 0.011695258986501015
# fold 3 epoch 120
# average train recon loss is: 0.12046161236623341
# average train ortho loss is: 0.010973496816148318
# fold 4 epoch 10
# average train recon loss is: 0.14588447155812795
# average train ortho loss is: 0.020554328463566352
# fold 4 epoch 20
# average train recon loss is: 0.13309936603242883
# average train ortho loss is: 0.011393423559276628
# fold 4 epoch 30
# average train recon loss is: 0.12751546484655915
# average train ortho loss is: 0.00981781245774305
# fold 4 epoch 40
# average train recon loss is: 0.12520638150650087
# average train ortho loss is: 0.009756678068488213
# fold 4 epoch 50
# average train recon loss is: 0.1237747136519045
# average train ortho loss is: 0.008024513197743244
# fold 4 epoch 60
# average train recon loss is: 0.12635131899781807
# average train ortho loss is: 0.030423192449194617
# fold 4 epoch 70
# average train recon loss is: 0.1235251901538801
# average train ortho loss is: 0.01539215058961174
# fold 4 epoch 80
# average train recon loss is: 0.12212810516357422
# average train ortho loss is: 0.014721650558535524
# fold 4 epoch 90
# average train recon loss is: 0.12352995453519303
# average train ortho loss is: 0.03639159352210775
# fold 4 epoch 100
# average train recon loss is: 0.12186553188946457
# average train ortho loss is: 0.017901952546011953
# fold 4 epoch 110
# average train recon loss is: 0.12062464678137871
# average train ortho loss is: 0.013215205858940858
# fold 4 epoch 120
# average train recon loss is: 0.12008657654957791
# average train ortho loss is: 0.012459007691139955
# fold 5 epoch 10
# average train recon loss is: 0.14528473643554893
# average train ortho loss is: 0.02029012562239848
# fold 5 epoch 20
# average train recon loss is: 0.13289009687493877
# average train ortho loss is: 0.011582104408222696
# fold 5 epoch 30
# average train recon loss is: 0.127570169825219
# average train ortho loss is: 0.01041219450757655
# fold 5 epoch 40
# average train recon loss is: 0.12531527149238714
# average train ortho loss is: 0.00911161378275192
# fold 5 epoch 50
# average train recon loss is: 0.12318683547718469
# average train ortho loss is: 0.008934564913395655
# fold 5 epoch 60
# average train recon loss is: 0.12209614224258473
# average train ortho loss is: 0.008001995350804217
# fold 5 epoch 70
# average train recon loss is: 0.1215727153829109
# average train ortho loss is: 0.007895768311709465
# fold 5 epoch 80
# average train recon loss is: 0.12067145806889869
# average train ortho loss is: 0.008601294039284505
# fold 5 epoch 90
# average train recon loss is: 0.12305536636939415
# average train ortho loss is: 0.016981617986757222
# fold 5 epoch 100
# average train recon loss is: 0.12047428032227583
# average train ortho loss is: 0.00865204637265923
# fold 5 epoch 110
# average train recon loss is: 0.11938481506296623
# average train ortho loss is: 0.007879441946645246
# [I 2024-06-13 13:45:04,798] Trial 98 finished with value: 0.2784283256261932 and parameters: {'lr': 0.006763947887948085, 'l2_lambda': 1.0514025104876472e-07, 'batch_size': 128, 'ortho_multiplier': 0.01, 'epoch': 120, 'l1_s1_out_dim': 512, 'l1_s2_out_dim': 64, 'l1_s12_out_dim': 1024, 'l2_s1_out_dim': 1024, 'l2_s2_out_dim': 64, 'l2_s12_out_dim': 256, 'l3_s1_out_dim': 32, 'l3_s2_out_dim': 256, 'l3_s12_out_dim': 1024, 'embed_s1_out_dim': 64, 'l1_s1_drop_rate': 0.1, 'l2_s1_drop_rate': 0.6, 'l3_s1_drop_rate': 0.2, 'embed_s1_drop_rate': 0.4, 'l1_s2_drop_rate': 0.6, 'l2_s2_drop_rate': 0.6, 'l3_s2_drop_rate': 0, 'embed_s2_drop_rate': 0.4, 'l1_s12_drop_rate': 0, 'l2_s12_drop_rate': 0, 'l3_s12_drop_rate': 0.6, 'embed_s12_drop_rate': 0.2, '_embed_s1_out_dim': 128, '_l3_s1_out_dim': 1024, '_l2_s1_out_dim': 512, '_embed_s2_out_dim': 32, '_l3_s2_out_dim': 64, '_l2_s2_out_dim': 1024, '_embed_s1_drop_rate': 0, '_l3_s1_drop_rate': 0.6, '_l2_s1_drop_rate': 0, '_l1_s1_drop_rate': 0, '_embed_s2_drop_rate': 0.6, '_l3_s2_drop_rate': 0.2, '_l2_s2_drop_rate': 0.2, '_l1_s2_drop_rate': 0.2}. Best is trial 93 with value: 0.081930275782426.
# fold 5 epoch 120
# average train recon loss is: 0.1190925242510129
# average train ortho loss is: 0.008807387738722224
# fold 1 epoch 10
# average train recon loss is: 0.09069501805006211
# average train ortho loss is: 0.043392907625461725
# fold 1 epoch 20
# average train recon loss is: 0.08680033344603981
# average train ortho loss is: 0.036658990931810194
# fold 1 epoch 30
# average train recon loss is: 0.0839536100251904
# average train ortho loss is: 0.02812137843175912
# fold 1 epoch 40
# average train recon loss is: 0.08148232304401477
# average train ortho loss is: 0.02800080586676817
# fold 1 epoch 50
# average train recon loss is: 0.07946151350332603
# average train ortho loss is: 0.020154692039330135
# fold 1 epoch 60
# average train recon loss is: 0.07779302876364735
# average train ortho loss is: 0.018673970410015794
# fold 1 epoch 70
# average train recon loss is: 0.07633260144349421
# average train ortho loss is: 0.012014784872781282
# fold 1 epoch 80
# average train recon loss is: 0.07490670112386408
# average train ortho loss is: 0.01140101923603393
# fold 1 epoch 90
# average train recon loss is: 0.07369506867859653
# average train ortho loss is: 0.01039367001425771
# fold 1 epoch 100
# average train recon loss is: 0.07246476177391148
# average train ortho loss is: 0.01064933373838289
# fold 1 epoch 110
# average train recon loss is: 0.07161121927045878
# average train ortho loss is: 0.008764577211196452
# fold 1 epoch 120
# average train recon loss is: 0.07073685394670175
# average train ortho loss is: 0.008313131232640733
# fold 2 epoch 10
# average train recon loss is: 0.09117759800356302
# average train ortho loss is: 0.035869269191470605
# fold 2 epoch 20
# average train recon loss is: 0.08731460890510591
# average train ortho loss is: 0.039742842478732186
# fold 2 epoch 30
# average train recon loss is: 0.0844183742251855
# average train ortho loss is: 0.039585159014458436
# fold 2 epoch 40
# average train recon loss is: 0.08183837954469306
# average train ortho loss is: 0.022769085034166917
# fold 2 epoch 50
# average train recon loss is: 0.07967993923809738
# average train ortho loss is: 0.02151456856827357
# fold 2 epoch 60
# average train recon loss is: 0.0778641066291841
# average train ortho loss is: 0.019029687737820038
# fold 2 epoch 70
# average train recon loss is: 0.07612759578178119
# average train ortho loss is: 0.014857724321437182
# fold 2 epoch 80
# average train recon loss is: 0.07477787927603621
# average train ortho loss is: 0.010601713268327912
# fold 2 epoch 90
# average train recon loss is: 0.07353704604144874
# average train ortho loss is: 0.008179538718826103
# fold 2 epoch 100
# average train recon loss is: 0.07240034286945933
# average train ortho loss is: 0.008305307112977096
# fold 2 epoch 110
# average train recon loss is: 0.07134480975163032
# average train ortho loss is: 0.007107270611878718
# fold 2 epoch 120
# average train recon loss is: 0.07059739563754414
# average train ortho loss is: 0.006292494969387932
# fold 3 epoch 10
# average train recon loss is: 0.09091130021226955
# average train ortho loss is: 0.03348348330254335
# fold 3 epoch 20
# average train recon loss is: 0.08719946889198973
# average train ortho loss is: 0.03262805380083028
# fold 3 epoch 30
# average train recon loss is: 0.08427035599074105
# average train ortho loss is: 0.0315391137510164
# fold 3 epoch 40
# average train recon loss is: 0.08177722148815458
# average train ortho loss is: 0.023874021673801055
# fold 3 epoch 50
# average train recon loss is: 0.07969846525950412
# average train ortho loss is: 0.01810468749521168
# fold 3 epoch 60
# average train recon loss is: 0.07792947042936062
# average train ortho loss is: 0.01615677797644707
# fold 3 epoch 70
# average train recon loss is: 0.07627133165942077
# average train ortho loss is: 0.01295704821662424
# fold 3 epoch 80
# average train recon loss is: 0.07495110005015608
# average train ortho loss is: 0.01002544478891285
# fold 3 epoch 90
# average train recon loss is: 0.07376258722409045
# average train ortho loss is: 0.00680607193184697
# fold 3 epoch 100
# average train recon loss is: 0.07255493706739098
# average train ortho loss is: 0.008090051846524162
# fold 3 epoch 110
# average train recon loss is: 0.07169872427585235
# average train ortho loss is: 0.007890789179622378
# fold 3 epoch 120
# average train recon loss is: 0.07076076044697142
# average train ortho loss is: 0.0056739928333330355
# fold 4 epoch 10
# average train recon loss is: 0.09087867896427171
# average train ortho loss is: 0.05410212592599781
# fold 4 epoch 20
# average train recon loss is: 0.08693173141160271
# average train ortho loss is: 0.02848799557865414
# fold 4 epoch 30
# average train recon loss is: 0.0840298959899647
# average train ortho loss is: 0.029422576856413647
# fold 4 epoch 40
# average train recon loss is: 0.08169095187007633
# average train ortho loss is: 0.024413249283156135
# fold 4 epoch 50
# average train recon loss is: 0.07958989801765985
# average train ortho loss is: 0.01680808586056761
# fold 4 epoch 60
# average train recon loss is: 0.07781463686891181
# average train ortho loss is: 0.017478567785797757
# fold 4 epoch 70
# average train recon loss is: 0.07613435529764725
# average train ortho loss is: 0.013246923111472669
# fold 4 epoch 80
# average train recon loss is: 0.07485615558704073
# average train ortho loss is: 0.012027671646373542
# fold 4 epoch 90
# average train recon loss is: 0.07361156511506275
# average train ortho loss is: 0.010792195348061279
# fold 4 epoch 100
# average train recon loss is: 0.07258277478078419
# average train ortho loss is: 0.007467324564147694
# fold 4 epoch 110
# average train recon loss is: 0.07171576910936683
# average train ortho loss is: 0.009871558364963931
# fold 4 epoch 120
# average train recon loss is: 0.07071627373475908
# average train ortho loss is: 0.008232423151886114
# fold 5 epoch 10
# average train recon loss is: 0.09079727759728065
# average train ortho loss is: 0.04929096882159893
# fold 5 epoch 20
# average train recon loss is: 0.08684559091676437
# average train ortho loss is: 0.040172327322306044
# fold 5 epoch 30
# average train recon loss is: 0.08388264761321919
# average train ortho loss is: 0.02787083287701559
# fold 5 epoch 40
# average train recon loss is: 0.08155078951730377
# average train ortho loss is: 0.027144077230855376
# fold 5 epoch 50
# average train recon loss is: 0.0795192543080818
# average train ortho loss is: 0.023991620062186966
# fold 5 epoch 60
# average train recon loss is: 0.07769726909522627
# average train ortho loss is: 0.01895726026101256
# fold 5 epoch 70
# average train recon loss is: 0.0763086554996146
# average train ortho loss is: 0.017681402107544965
# fold 5 epoch 80
# average train recon loss is: 0.07498657264837054
# average train ortho loss is: 0.01303114749516133
# fold 5 epoch 90
# average train recon loss is: 0.07370025258399172
# average train ortho loss is: 0.016034820606078592
# fold 5 epoch 100
# average train recon loss is: 0.07249820511476651
# average train ortho loss is: 0.012043278552218026
# fold 5 epoch 110
# average train recon loss is: 0.07138559730555301
# average train ortho loss is: 0.009691161355844708
# fold 5 epoch 120
# average train recon loss is: 0.07050516613351063
# average train ortho loss is: 0.009409958203899421
# [I 2024-06-13 13:54:53,463] Trial 99 finished with value: 0.1405017397281476 and parameters: {'lr': 0.0031892817618749017, 'l2_lambda': 1.741047323129571e-07, 'batch_size': 512, 'ortho_multiplier': 0.01, 'epoch': 120, 'l1_s1_out_dim': 128, 'l1_s2_out_dim': 64, 'l1_s12_out_dim': 1024, 'l2_s1_out_dim': 256, 'l2_s2_out_dim': 512, 'l2_s12_out_dim': 256, 'l3_s1_out_dim': 32, 'l3_s2_out_dim': 32, 'l3_s12_out_dim': 512, 'embed_s1_out_dim': 64, 'l1_s1_drop_rate': 0.1, 'l2_s1_drop_rate': 0, 'l3_s1_drop_rate': 0.2, 'embed_s1_drop_rate': 0.4, 'l1_s2_drop_rate': 0.6, 'l2_s2_drop_rate': 0.6, 'l3_s2_drop_rate': 0, 'embed_s2_drop_rate': 0.4, 'l1_s12_drop_rate': 0.1, 'l2_s12_drop_rate': 0, 'l3_s12_drop_rate': 0.6, 'embed_s12_drop_rate': 0.2, '_embed_s1_out_dim': 128, '_l3_s1_out_dim': 1024, '_l2_s1_out_dim': 512, '_embed_s2_out_dim': 32, '_l3_s2_out_dim': 1024, '_l2_s2_out_dim': 1024, '_embed_s1_drop_rate': 0, '_l3_s1_drop_rate': 0.6, '_l2_s1_drop_rate': 0, '_l1_s1_drop_rate': 0, '_embed_s2_drop_rate': 0.6, '_l3_s2_drop_rate': 0.6, '_l2_s2_drop_rate': 0.2, '_l1_s2_drop_rate': 0.2}. Best is trial 93 with value: 0.081930275782426.
# Elapsed time: 1047.6646192391713 minutes
